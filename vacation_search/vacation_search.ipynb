# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("/Users/lukehg/Desktop/DA_class/week_6/world_weather_analysis/weather_database/weatherpy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Punta Arenas      CL -53.1500  -70.9167     46.51        71
# 1        1   New Norfolk      AU -42.7826  147.0587     38.91        87
# 2        2    Georgetown      MY   5.4112  100.3354     80.53        95
# 3        3     Busselton      AU -33.6500  115.3333     60.87        83
# 4        4     Jamestown      US  42.0970  -79.2353     80.24        65
#
#    Cloudiness  Wind Speed Current Description
# 0          40       28.77    scattered clouds
# 1          63        1.01       broken clouds
# 2          20        5.01          few clouds
# 3           0       10.07           clear sky
# 4          40       11.50    scattered clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID                  City Country      Lat       Lng  Max Temp  \
# 2         2            Georgetown      MY   5.4112  100.3354     80.53
# 4         4             Jamestown      US  42.0970  -79.2353     80.24
# 7         7  Vila Franca Do Campo      PT  37.7167  -25.4333     71.20
# 8         8                  Aksu      CN  41.1231   80.2644     78.08
# 9         9               Safford      US  32.8340 -109.7076     83.12
# 13       13              Victoria      HK  22.2855  114.1577     85.32
# 14       14               Rikitea      PF -23.1203 -134.9692     75.02
# 16       16             Namatanai      PG  -3.6667  152.4333     79.66
# 17       17                Torbay      CA  47.6666  -52.7314     79.57
# 19       19                 Kapaa      US  22.0752 -159.3190     82.38
#
#     Humidity  Cloudiness  Wind Speed Current Description
# 2         95          20        5.01          few clouds
# 4         65          40       11.50    scattered clouds
# ...

# %%
# 4a. Determine if there are any empty rows.
nan_rows = preferred_cities_df[preferred_cities_df.isna().any(axis=1)]

print(nan_rows)
# Out:
#      City_ID        City Country      Lat      Lng  Max Temp  Humidity  \
# 43        43    Luderitz     NaN -26.6481  15.1594     74.95        36
# 391      391  Walvis Bay     NaN -22.9575  14.5053     79.75        21
#
#      Cloudiness  Wind Speed Current Description
# 43            0       24.47           clear sky
# 391           0       18.41           clear sky

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
pref_cities_df = preferred_cities_df.dropna(axis = 0)

pref_cities_df.head(50)
# Out:
#      City_ID                  City Country      Lat       Lng  Max Temp  \
# 2          2            Georgetown      MY   5.4112  100.3354     80.53
# 4          4             Jamestown      US  42.0970  -79.2353     80.24
# 7          7  Vila Franca Do Campo      PT  37.7167  -25.4333     71.20
# 8          8                  Aksu      CN  41.1231   80.2644     78.08
# 9          9               Safford      US  32.8340 -109.7076     83.12
# 13        13              Victoria      HK  22.2855  114.1577     85.32
# 14        14               Rikitea      PF -23.1203 -134.9692     75.02
# 16        16             Namatanai      PG  -3.6667  152.4333     79.66
# 17        17                Torbay      CA  47.6666  -52.7314     79.57
# 19        19                 Kapaa      US  22.0752 -159.3190     82.38
# 20        20               Pokhara      NP  28.2333   83.9833     72.55
# 21        21           Robertsport      LR   6.7533  -11.3686     78.94
# ...

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = pref_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                     City Country  Max Temp Current Description      Lat  \
# 2             Georgetown      MY     80.53          few clouds   5.4112
# 4              Jamestown      US     80.24    scattered clouds  42.0970
# 7   Vila Franca Do Campo      PT     71.20     overcast clouds  37.7167
# 8                   Aksu      CN     78.08           clear sky  41.1231
# 9                Safford      US     83.12       broken clouds  32.8340
# 13              Victoria      HK     85.32       broken clouds  22.2855
# 14               Rikitea      PF     75.02           clear sky -23.1203
# 16             Namatanai      PG     79.66          light rain  -3.6667
# 17                Torbay      CA     79.57    scattered clouds  47.6666
# 19                 Kapaa      US     82.38          few clouds  22.0752
#
#          Lng Hotel Name
# 2   100.3354
# 4   -79.2353
# 7   -25.4333
# 8    80.2644
# 9  -109.7076
# 13  114.1577
# 14 -134.9692
# 16  152.4333
# 17  -52.7314
# 19 -159.3190

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found ... skipping")
# Out:
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping
# Hotel not found ... skipping

# %%
hotel_df.head(50)
# Out:
#                      City Country  Max Temp           Current Description  \
# 2              Georgetown      MY     80.53                    few clouds
# 4               Jamestown      US     80.24              scattered clouds
# 7    Vila Franca Do Campo      PT     71.20               overcast clouds
# 8                    Aksu      CN     78.08                     clear sky
# 9                 Safford      US     83.12                 broken clouds
# 13               Victoria      HK     85.32                 broken clouds
# 14                Rikitea      PF     75.02                     clear sky
# 16              Namatanai      PG     79.66                    light rain
# 17                 Torbay      CA     79.57              scattered clouds
# 19                  Kapaa      US     82.38                    few clouds
# 20                Pokhara      NP     72.55               overcast clouds
# 21            Robertsport      LR     78.94               overcast clouds
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.

nan_rows = hotel_df[hotel_df.isna().any(axis=1)]


# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
pref_hotel_df = hotel_df.dropna(axis = 0)

pref_hotel_df.head(50)
# Out:
#                      City Country  Max Temp           Current Description  \
# 2              Georgetown      MY     80.53                    few clouds
# 4               Jamestown      US     80.24              scattered clouds
# 7    Vila Franca Do Campo      PT     71.20               overcast clouds
# 8                    Aksu      CN     78.08                     clear sky
# 9                 Safford      US     83.12                 broken clouds
# 13               Victoria      HK     85.32                 broken clouds
# 14                Rikitea      PF     75.02                     clear sky
# 16              Namatanai      PG     79.66                    light rain
# 17                 Torbay      CA     79.57              scattered clouds
# 19                  Kapaa      US     82.38                    few clouds
# 20                Pokhara      NP     72.55               overcast clouds
# 21            Robertsport      LR     78.94               overcast clouds
# ...

# %%
# 8a. Create the output File (CSV)
# Create the output file (CSV).
output_data_file = "/Users/lukehg/Desktop/DA_class/week_6/vacation_search/weatherpy_vacation.csv"
# 8b. Export the City_Data into a CSV.
pref_cities_df.to_csv(output_data_file, index_label="City_ID")
# 8b. Export the City_Data into a csv
pref_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
fig = gmaps.figure()

info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in pref_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = pref_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
